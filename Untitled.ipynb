# %%
from art import *
Art=text2art("art",font='block',chr_ignore=True)

# %%
Art
# Out:
# "\r\n .----------------.  .----------------.  .----------------.\r\n| .--------------. || .--------------. || .--------------. |\r\n| |      __      | || |  _______     | || |  _________   | |\r\n| |     /  \\     | || | |_   __ \\    | || | |  _   _  |  | |\r\n| |    / /\\ \\    | || |   | |__) |   | || | |_/ | | \\_|  | |\r\n| |   / ____ \\   | || |   |  __ /    | || |     | |      | |\r\n| | _/ /    \\ \\_ | || |  _| |  \\ \\_  | || |    _| |_     | |\r\n| ||____|  |____|| || | |____| |___| | || |   |_____|    | |\r\n| |              | || |              | || |              | |\r\n| '--------------' || '--------------' || '--------------' |\r\n '----------------'  '----------------'  '----------------'\r\n"

# %%
Art=text2art("zach noble","rand")
print(Art)
# Out:
#
#                |                  |    |
# ,---,,---.,---.|---.    ,---.,---.|---.|    ,---.
#  .-' ,---||    |   |    |   ||   ||   ||    |---'
# '---'`---^`---'`   '    `   '`---'`---'`---'`---'

# %%
import ascii
output = ascii.loadFromUrl("")
print(output)
# Out:
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# ...

# %%
import ascii
output = ascii.loadFromUrl("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRg5CxDfp-91VxYm3wPvbNzgSUsgaJJ6NKITAYV9ZjLBuOhAjfz")
print(output)
# Out:
# 8800008888080000000000000GGGG0088888880000088CGGtfC0f0fGLC0C
# 00000888888000000000000000GGGGG008888880000008C0f1Cf0CGL0C08
# 00008888000000000000GGGGGGGGGGGGGG088888008000GGG1fffGfGC00C
# 000080880G000000000GGGGGGGCGGfGGGGG088888008880GCL1fGLGLGfC8
# 00888000000000GG00000Gi;i:itiL;1itCG0888880000800Cfff00GLGG0
# 088888G00000GG00000GCi,11i;:tttLttC0GG088800800008fLtC0CGLG0
# 88808G0G0GG000G0Ci:i;tit1tt1Ltftt;itfC008880000000GGiL0CCGG8
# 8880GGGGGC00G0C;11tt;1t1ft1111tfftif1GG088880000800GLLLGCCGL
# 8008GGGGGG;;:;:t1tfttftfti11iLtL1tf1iGGG0088000000L0CfLLGLGG
# 88@GCCLf1;f1ftt1ttttttiii11tf1tfttfi1GGGG0880000008GGGtCC0G0
# 80GCCC:1it1Lt1tttfLf11tftifLftttftLf10GGG0080000000CCGC1LCGG
# 08CCL;ti1t1i1ft1ft1ftf1tftffftftftftffGGGG0888000008CCCLfLGG
# 0GCLi1:t11t11f1tff1111tttfff1ftftffL11f0GG00880000000CLGLLGf
# 0CL;f;;tt1titf11tftttftttttfttf1ft1tft10GGG088000000080GCLfC
# CCt1i1t1t1itfff1fttfft1fftttt1ttfftitfC;CGG008800000G000GCLf
# ...

# %%
import numpy as np
point_1 = (2, 3, 5)
point_2 = (1, -1, 3)

manhattan_distance = 0
for i in range(3):
    manhattan_distance += np.abs(point_1[i] - point_2[i])

# %%
manhattan_distance
# Out:
# 7
